# %%
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import joblib

# %%
df2 = pd.read_csv('/content/dataset-prediksi-sem2.csv')
df3 = pd.read_csv('/content/dataset-prediksi-sem3.csv')
df4 = pd.read_csv('/content/dataset-prediksi-sem4.csv')
df5 = pd.read_csv('/content/dataset-prediksi-sem5.csv')
df6 = pd.read_csv('/content/dataset-prediksi-sem6.csv')
df7 = pd.read_csv('/content/dataset-prediksi-sem7.csv')
df8 = pd.read_csv('/content/dataset-prediksi-sem8.csv')

# %%
df2.head(5)
# Out:
#        nama  ips-now  ips-next
# 0  Taruna-1     3.76      3.57
# 1  Taruna-2     3.71      3.65
# 2  Taruna-3     3.91      3.52
# 3  Taruna-4     3.93      3.60
# 4  Taruna-5     3.87      3.65

# %%
df3.head(5)
# Out:
#        nama  ips-now  ips-next
# 0  Taruna-1     3.57      3.98
# 1  Taruna-2     3.65      3.95
# 2  Taruna-3     3.52      3.81
# 3  Taruna-4     3.60      3.88
# 4  Taruna-5     3.65      3.94

# %%
df4.head(5)
# Out:
#        nama  ips-now  ips-next
# 0  Taruna-1     3.98      3.85
# 1  Taruna-2     3.95      3.90
# 2  Taruna-3     3.81      3.81
# 3  Taruna-4     3.88      3.85
# 4  Taruna-5     3.94      3.91

# %%
df5.head(5)
# Out:
#        nama  ips-now  ips-next
# 0  Taruna-1     3.85      3.98
# 1  Taruna-2     3.90      3.96
# 2  Taruna-3     3.81      3.93
# 3  Taruna-4     3.85      3.94
# 4  Taruna-5     3.91      3.90

# %%
df6.head(5)
# Out:
#        nama  ips-now  ips-next
# 0  Taruna-1     3.98      3.98
# 1  Taruna-2     3.96      3.91
# 2  Taruna-3     3.93      3.91
# 3  Taruna-4     3.94      3.99
# 4  Taruna-5     3.90      3.98

# %%
df7.head(5)
# Out:
#        nama  ips-now  ips-next
# 0  Taruna-1     3.98      3.99
# 1  Taruna-2     3.91      3.96
# 2  Taruna-3     3.91      3.97
# 3  Taruna-4     3.99      3.98
# 4  Taruna-5     3.98      4.00

# %%
df8.head(5)
# Out:
#        nama  ips-now  ips-next
# 0  Taruna-1     3.99      3.87
# 1  Taruna-2     3.96      3.86
# 2  Taruna-3     3.97      3.84
# 3  Taruna-4     3.98      3.88
# 4  Taruna-5     4.00      3.89

# %%
X2 = df2['ips-now']
X3 = df3['ips-now']
X4 = df4['ips-now']
X5 = df5['ips-now']
X6 = df6['ips-now']
X7 = df7['ips-now']
X8 = df8['ips-now']

# %%
y2 = df2['ips-next']
y3 = df3['ips-next']
y4 = df4['ips-next']
y5 = df5['ips-next']
y6 = df6['ips-next']
y7 = df7['ips-next']
y8 = df8['ips-next']

# %%
# Dataset prediksi sem2
X2_train, X2_temp, y2_train, y2_temp = train_test_split(X2, y2, test_size=0.3, random_state=42)
X2_val, X2_test, y2_val, y2_test = train_test_split(X2_temp, y2_temp, test_size=0.5, random_state=42)
X2_train_reshaped = X2_train.values.reshape(-1, 1)
X2_val_reshaped = X2_val.values.reshape(-1, 1)
X2_test_reshaped = X2_test.values.reshape(-1, 1)

# %%
# Dataset prediksi sem3
X3_train, X3_temp, y3_train, y3_temp = train_test_split(X3, y3, test_size=0.3, random_state=42)
X3_val, X3_test, y3_val, y3_test = train_test_split(X3_temp, y3_temp, test_size=0.5, random_state=42)
X3_train_reshaped = X3_train.values.reshape(-1, 1)
X3_val_reshaped = X3_val.values.reshape(-1, 1)
X3_test_reshaped = X3_test.values.reshape(-1, 1)

# %%
# Dataset prediksi sem2
X4_train, X4_temp, y4_train, y4_temp = train_test_split(X4, y4, test_size=0.3, random_state=42)
X4_val, X4_test, y4_val, y4_test = train_test_split(X4_temp, y4_temp, test_size=0.5, random_state=42)
X4_train_reshaped = X4_train.values.reshape(-1, 1)
X4_val_reshaped = X4_val.values.reshape(-1, 1)
X4_test_reshaped = X4_test.values.reshape(-1, 1)

# %%
# Dataset prediksi sem2
X5_train, X5_temp, y5_train, y5_temp = train_test_split(X5, y5, test_size=0.3, random_state=42)
X5_val, X5_test, y5_val, y5_test = train_test_split(X5_temp, y5_temp, test_size=0.5, random_state=42)
X5_train_reshaped = X5_train.values.reshape(-1, 1)
X5_val_reshaped = X5_val.values.reshape(-1, 1)
X5_test_reshaped = X5_test.values.reshape(-1, 1)

# %%
# Dataset prediksi sem2
X6_train, X6_temp, y6_train, y6_temp = train_test_split(X6, y6, test_size=0.3, random_state=42)
X6_val, X6_test, y6_val, y6_test = train_test_split(X6_temp, y6_temp, test_size=0.5, random_state=42)
X6_train_reshaped = X6_train.values.reshape(-1, 1)
X6_val_reshaped = X6_val.values.reshape(-1, 1)
X6_test_reshaped = X6_test.values.reshape(-1, 1)

# %%
# Dataset prediksi sem2
X7_train, X7_temp, y7_train, y7_temp = train_test_split(X7, y7, test_size=0.3, random_state=42)
X7_val, X7_test, y7_val, y7_test = train_test_split(X7_temp, y7_temp, test_size=0.5, random_state=42)
X7_train_reshaped = X7_train.values.reshape(-1, 1)
X7_val_reshaped = X7_val.values.reshape(-1, 1)
X7_test_reshaped = X7_test.values.reshape(-1, 1)

# %%
# Dataset prediksi sem2
X8_train, X8_temp, y8_train, y8_temp = train_test_split(X8, y8, test_size=0.3, random_state=42)
X8_val, X8_test, y8_val, y8_test = train_test_split(X8_temp, y8_temp, test_size=0.5, random_state=42)
X8_train_reshaped = X8_train.values.reshape(-1, 1)
X8_val_reshaped = X8_val.values.reshape(-1, 1)
X8_test_reshaped = X8_test.values.reshape(-1, 1)

# %%
model = MLPRegressor(hidden_layer_sizes=(8, 8, 8, 8, 8, 8, 8), max_iter=100, random_state=42, solver='sgd', learning_rate='invscaling', early_stopping=True, n_iter_no_change=10)

# %%
# Latih, validasi, dan uji model sem2
training_sem2 = model.fit(X2_train_reshaped, y2_train)
validating_sem2 = model.predict(X2_val_reshaped)
testing_sem2 = model.predict(X2_test_reshaped)

# %%
#evaluasi pada data validasi
mse_val_sem2 = mean_squared_error(y2_val, validating_sem2)
r2_val_sem2 = r2_score(y2_val, validating_sem2)

#evaluasi pada data uji
mse_test_sem2 = mean_squared_error(y2_test, testing_sem2)
r2_test_sem2 = r2_score(y2_test, testing_sem2)

# %%
# Menampilkan hasil evaluasi
print(f"MSE (Validation): {mse_val_sem2}")
print(f"R-squared (Validation): {r2_val_sem2}")
print(f"MSE (Test): {mse_test_sem2}")
print(f"R-squared (Test): {r2_test_sem2}")
# Out:
# MSE (Validation): 0.0033529090956541077
# R-squared (Validation): -0.01107187719739966
# MSE (Test): 0.003408716823348889
# R-squared (Test): -0.010683007640050368

# %%
# Plot hasil prediksi pada data validasi dan data uji
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.scatter(y2_val, validating_sem2)
plt.title(f"MLP Regressor - Semester 2 - Validation Set")
plt.xlabel("True Values")
plt.ylabel("Predictions")
# Out:
# Text(0, 0.5, 'Predictions')

# %%
# Plot hasil prediksi pada data validasi dan data uji
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.scatter(y2_test, testing_sem2)
plt.title(f"MLP Regressor - Semester 2 - Testing Set")
plt.xlabel("True Values")
plt.ylabel("Predictions")
# Out:
# Text(0, 0.5, 'Predictions')

# %%
# Grafik Residual
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
residuals = y2_test - testing_sem2
plt.scatter(testing_sem2, residuals)
plt.title("Residual Plot Semester 2")
plt.xlabel("Predictions")
plt.ylabel("Residuals")
# Out:
# Text(0, 0.5, 'Residuals')

# %%
# Grafik Normalitas Residual
plt.subplot(2, 2, 2)
sns.histplot(residuals, kde=True)
plt.title("Residual Normality Plot Semester 2")
plt.xlabel("Residuals")
# Out:
# Text(0.5, 0, 'Residuals')

# %%
# Latih, validasi, dan uji model sem3
training_sem3 = model.fit(X3_train_reshaped, y3_train)
validating_sem3 = model.predict(X3_val_reshaped)
testing_sem3 = model.predict(X3_test_reshaped)

# %%
#evaluasi pada data validasi
mse_val_sem3 = mean_squared_error(y3_val, validating_sem3)
r2_val_sem3 = r2_score(y3_val, validating_sem3)

#evaluasi pada data uji
mse_test_sem3 = mean_squared_error(y3_test, testing_sem3)
r2_test_sem3 = r2_score(y3_test, testing_sem3)

# %%
# Menampilkan hasil evaluasi
print(f"MSE (Validation): {mse_val_sem3}")
print(f"R-squared (Validation): {r2_val_sem3}")
print(f"MSE (Test): {mse_test_sem3}")
print(f"R-squared (Test): {r2_test_sem3}")
# Out:
# MSE (Validation): 0.005267868143886686
# R-squared (Validation): -0.005376803525474427
# MSE (Test): 0.00519119964850837
# R-squared (Test): -0.00477309534453596

# %%
# Plot hasil prediksi pada data validasi dan data uji
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.scatter(y3_val, validating_sem3)
plt.title(f"MLP Regressor - Semester 3 - Validation Set")
plt.xlabel("True Values")
plt.ylabel("Predictions")
# Out:
# Text(0, 0.5, 'Predictions')

# %%
# Plot hasil prediksi pada data validasi dan data uji
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.scatter(y3_test, testing_sem3)
plt.title(f"MLP Regressor - Semester 3 - Testing Set")
plt.xlabel("True Values")
plt.ylabel("Predictions")
# Out:
# Text(0, 0.5, 'Predictions')

# %%
# Grafik Residual
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
residuals = y3_test - testing_sem3
plt.scatter(testing_sem3, residuals)
plt.title("Residual Plot Semester 3")
plt.xlabel("Predictions")
plt.ylabel("Residuals")
# Out:
# Text(0, 0.5, 'Residuals')

# %%
# Grafik Normalitas Residual
plt.subplot(2, 2, 2)
sns.histplot(residuals, kde=True)
plt.title("Residual Normality Plot Semester 3")
plt.xlabel("Residuals")
# Out:
# Text(0.5, 0, 'Residuals')

# %%
# Latih, validasi, dan uji model sem4
training_sem4 = model.fit(X4_train_reshaped, y4_train)
validating_sem4 = model.predict(X4_val_reshaped)
testing_sem4 = model.predict(X4_test_reshaped)

# %%
#evaluasi pada data validasi
mse_val_sem4 = mean_squared_error(y4_val, validating_sem4)
r2_val_sem4 = r2_score(y4_val, validating_sem4)

#evaluasi pada data uji
mse_test_sem4 = mean_squared_error(y4_test, testing_sem4)
r2_test_sem4 = r2_score(y4_test, testing_sem4)

# %%
# Menampilkan hasil evaluasi
print(f"MSE (Validation): {mse_val_sem4}")
print(f"R-squared (Validation): {r2_val_sem4}")
print(f"MSE (Test): {mse_test_sem4}")
print(f"R-squared (Test): {r2_test_sem4}")
# Out:
# MSE (Validation): 0.0033573905178685727
# R-squared (Validation): -0.007844437873081533
# MSE (Test): 0.0034172993832181
# R-squared (Test): -0.008698657239832208

# %%
# Plot hasil prediksi pada data validasi dan data uji
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.scatter(y4_val, validating_sem4)
plt.title(f"MLP Regressor - Semester 4 - Validation Set")
plt.xlabel("True Values")
plt.ylabel("Predictions")
# Out:
# Text(0, 0.5, 'Predictions')

# %%
# Plot hasil prediksi pada data validasi dan data uji
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.scatter(y4_test, testing_sem4)
plt.title(f"MLP Regressor - Semester 4 - Testing Set")
plt.xlabel("True Values")
plt.ylabel("Predictions")
# Out:
# Text(0, 0.5, 'Predictions')

# %%
# Grafik Residual
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
residuals = y4_test - testing_sem4
plt.scatter(testing_sem4, residuals)
plt.title("Residual Plot Semester 4")
plt.xlabel("Predictions")
plt.ylabel("Residuals")
# Out:
# Text(0, 0.5, 'Residuals')

# %%
# Grafik Normalitas Residual
plt.subplot(2, 2, 2)
sns.histplot(residuals, kde=True)
plt.title("Residual Normality Plot Semester 4")
plt.xlabel("Residuals")
# Out:
# Text(0.5, 0, 'Residuals')

# %%
# Latih, validasi, dan uji model sem5
training_sem5 = model.fit(X5_train_reshaped, y5_train)
validating_sem5 = model.predict(X5_val_reshaped)
testing_sem5 = model.predict(X5_test_reshaped)

# %%
#evaluasi pada data validasi
mse_val_sem5 = mean_squared_error(y5_val, validating_sem5)
r2_val_sem5 = r2_score(y5_val, validating_sem5)

#evaluasi pada data uji
mse_test_sem5 = mean_squared_error(y5_test, testing_sem5)
r2_test_sem5 = r2_score(y5_test, testing_sem5)

# %%
# Menampilkan hasil evaluasi
print(f"MSE (Validation): {mse_val_sem5}")
print(f"R-squared (Validation): {r2_val_sem5}")
print(f"MSE (Test): {mse_test_sem5}")
print(f"R-squared (Test): {r2_test_sem5}")
# Out:
# MSE (Validation): 0.0019384599548385284
# R-squared (Validation): -0.010452865190455851
# MSE (Test): 0.0019027222031344224
# R-squared (Test): -0.01255454883563556

# %%
# Plot hasil prediksi pada data validasi dan data uji
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.scatter(y5_val, validating_sem5)
plt.title(f"MLP Regressor - Semester 5 - Validation Set")
plt.xlabel("True Values")
plt.ylabel("Predictions")
# Out:
# Text(0, 0.5, 'Predictions')

# %%
# Plot hasil prediksi pada data validasi dan data uji
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.scatter(y5_test, testing_sem5)
plt.title(f"MLP Regressor - Semester 5 - Testing Set")
plt.xlabel("True Values")
plt.ylabel("Predictions")
# Out:
# Text(0, 0.5, 'Predictions')

# %%
# Grafik Residual
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
residuals = y5_test - testing_sem5
plt.scatter(testing_sem5, residuals)
plt.title("Residual Plot Semester 5")
plt.xlabel("Predictions")
plt.ylabel("Residuals")
# Out:
# Text(0, 0.5, 'Residuals')

# %%
# Grafik Normalitas Residual
plt.subplot(2, 2, 2)
sns.histplot(residuals, kde=True)
plt.title("Residual Normality Plot Semester 5")
plt.xlabel("Residuals")
# Out:
# Text(0.5, 0, 'Residuals')

# %%
# Latih, validasi, dan uji model sem6
training_sem6 = model.fit(X6_train_reshaped, y6_train)
validating_sem6 = model.predict(X6_val_reshaped)
testing_sem6 = model.predict(X6_test_reshaped)

# %%
#evaluasi pada data validasi
mse_val_sem6 = mean_squared_error(y6_val, validating_sem6)
r2_val_sem6 = r2_score(y6_val, validating_sem6)

#evaluasi pada data uji
mse_test_sem6 = mean_squared_error(y6_test, testing_sem6)
r2_test_sem6 = r2_score(y6_test, testing_sem6)

# %%
# Menampilkan hasil evaluasi
print(f"MSE (Validation): {mse_val_sem6}")
print(f"R-squared (Validation): {r2_val_sem6}")
print(f"MSE (Test): {mse_test_sem6}")
print(f"R-squared (Test): {r2_test_sem6}")
# Out:
# MSE (Validation): 0.0008669162194024578
# R-squared (Validation): -0.012819445679562058
# MSE (Test): 0.0008547155433997131
# R-squared (Test): -0.013057372441441117

# %%
# Plot hasil prediksi pada data validasi dan data uji
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.scatter(y6_val, validating_sem6)
plt.title(f"MLP Regressor - Semester 6 - Validation Set")
plt.xlabel("True Values")
plt.ylabel("Predictions")
# Out:
# Text(0, 0.5, 'Predictions')

# %%
# Plot hasil prediksi pada data validasi dan data uji
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.scatter(y6_test, testing_sem6)
plt.title(f"MLP Regressor - Semester 6 - Testing Set")
plt.xlabel("True Values")
plt.ylabel("Predictions")
# Out:
# Text(0, 0.5, 'Predictions')

# %%
# Grafik Residual
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
residuals = y6_test - testing_sem6
plt.scatter(testing_sem6, residuals)
plt.title("Residual Plot Semester 6")
plt.xlabel("Predictions")
plt.ylabel("Residuals")
# Out:
# Text(0, 0.5, 'Residuals')

# %%
# Grafik Normalitas Residual
plt.subplot(2, 2, 2)
sns.histplot(residuals, kde=True)
plt.title("Residual Normality Plot Semester 6")
plt.xlabel("Residuals")
# Out:
# Text(0.5, 0, 'Residuals')

# %%
# Latih, validasi, dan uji model sem2
training_sem7 = model.fit(X7_train_reshaped, y7_train)
validating_sem7 = model.predict(X7_val_reshaped)
testing_sem7 = model.predict(X7_test_reshaped)

# %%
#evaluasi pada data validasi
mse_val_sem7 = mean_squared_error(y7_val, validating_sem7)
r2_val_sem7 = r2_score(y7_val, validating_sem7)

#evaluasi pada data uji
mse_test_sem7 = mean_squared_error(y7_test, testing_sem7)
r2_test_sem7 = r2_score(y7_test, testing_sem7)

# %%
# Menampilkan hasil evaluasi
print(f"MSE (Validation): {mse_val_sem7}")
print(f"R-squared (Validation): {r2_val_sem7}")
print(f"MSE (Test): {mse_test_sem7}")
print(f"R-squared (Test): {r2_test_sem7}")
# Out:
# MSE (Validation): 0.00023012044432869048
# R-squared (Validation): -0.02301855214402959
# MSE (Test): 0.0002344674840182575
# R-squared (Test): -0.023142895820245313

# %%
# Plot hasil prediksi pada data validasi dan data uji
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.scatter(y7_val, validating_sem7)
plt.title(f"MLP Regressor - Semester 7 - Validation Set")
plt.xlabel("True Values")
plt.ylabel("Predictions")
# Out:
# Text(0, 0.5, 'Predictions')

# %%
# Plot hasil prediksi pada data validasi dan data uji
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.scatter(y7_test, testing_sem7)
plt.title(f"MLP Regressor - Semester 7 - Testing Set")
plt.xlabel("True Values")
plt.ylabel("Predictions")
# Out:
# Text(0, 0.5, 'Predictions')

# %%
# Grafik Residual
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
residuals = y7_test - testing_sem7
plt.scatter(testing_sem7, residuals)
plt.title("Residual Plot Semester 7")
plt.xlabel("Predictions")
plt.ylabel("Residuals")
# Out:
# Text(0, 0.5, 'Residuals')

# %%
# Grafik Normalitas Residual
plt.subplot(2, 2, 2)
sns.histplot(residuals, kde=True)
plt.title("Residual Normality Plot Semester 7")
plt.xlabel("Residuals")
# Out:
# Text(0.5, 0, 'Residuals')

# %%
# Latih, validasi, dan uji model sem8
training_sem8 = model.fit(X8_train_reshaped, y8_train)
validating_sem8 = model.predict(X8_val_reshaped)
testing_sem8 = model.predict(X8_test_reshaped)

# %%
#evaluasi pada data validasi
mse_val_sem8 = mean_squared_error(y8_val, validating_sem8)
r2_val_sem8 = r2_score(y8_val, validating_sem8)

#evaluasi pada data uji
mse_test_sem8 = mean_squared_error(y8_test, testing_sem8)
r2_test_sem8 = r2_score(y8_test, testing_sem8)

# %%
# Menampilkan hasil evaluasi
print(f"MSE (Validation): {mse_val_sem8}")
print(f"R-squared (Validation): {r2_val_sem8}")
print(f"MSE (Test): {mse_test_sem8}")
print(f"R-squared (Test): {r2_test_sem8}")
# Out:
# MSE (Validation): 0.000464320030387415
# R-squared (Validation): 0.007563468985478772
# MSE (Test): 0.00046055750025650614
# R-squared (Test): 0.00802726262017961

# %%
# Plot hasil prediksi pada data validasi dan data uji
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.scatter(y8_val, validating_sem8)
plt.title(f"MLP Regressor - Semester 8 - Validation Set")
plt.xlabel("True Values")
plt.ylabel("Predictions")
# Out:
# Text(0, 0.5, 'Predictions')

# %%
# Plot hasil prediksi pada data validasi dan data uji
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.scatter(y8_test, testing_sem8)
plt.title(f"MLP Regressor - Semester 8 - Testing Set")
plt.xlabel("True Values")
plt.ylabel("Predictions")
# Out:
# Text(0, 0.5, 'Predictions')

# %%
# Grafik Residual
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
residuals = y8_test - testing_sem8
plt.scatter(testing_sem8, residuals)
plt.title("Residual Plot Semester 8")
plt.xlabel("Predictions")
plt.ylabel("Residuals")
# Out:
# Text(0, 0.5, 'Residuals')

# %%
# Grafik Normalitas Residual
plt.subplot(2, 2, 2)
sns.histplot(residuals, kde=True)
plt.title("Residual Normality Plot Semester 8")
plt.xlabel("Residuals")
# Out:
# Text(0.5, 0, 'Residuals')

# %%
joblib.dump(model, 'MLPRegressor-8neurons-7depth-sgd-invscaling.joblib')
# Out:
# ['MLPRegressor-8neurons-7depth-sgd-invscaling.joblib']
